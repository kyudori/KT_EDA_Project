# %% [markdown]
# # 안녕하세요^^
# ## '서울시 생활정보 기반 대중교통 수요 분석 ' 과정에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.
# ### "구별 등록인구 데이터" 를 확인해 보도록 하겠습니다

# %%
# 필요 라이브러리부터 설치합니다.
# %pip install pandas seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\khh53\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: seaborn in c:\users\khh53\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\khh53\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\khh53\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\khh53\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\khh53\anaconda3\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\khh53\anaconda3\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\khh53\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\khh53\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\khh53\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\khh53\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\khh53\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\khh53\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\khh53\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 데이터는 'raw_data' 폴더에 있습니다.
#
# [기본 데이터]
# * 1.3 seoul_people.csv
#
# [데이터 소개]
# * 서울 시 주민 등록 데이터
#
# [변수 소개]
# * 한국인 / 등록 외국인 / 합계 / 세대수 / 고령인구수

# %% [markdown]
# # 1.데이터 불러오기
# ### 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터라고 할 수 있습니다.
# + KeyPoint : 불러오고자 하는 데이터에 따라 자유롭게 변수로 지정할 수 있다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(여기서는 CSV 기준으로 진행)
# * csv : pd.read_csv("파일이름. csv")
# * txt : pd.read_csv("파일이름. csv", sep="구분자")
# * xlsx : pd.read_excel('파일이름.xlsx')
# * pickle : pd.read_pickle("파일이름.pkl") <br>
#  [참고] pickle은 파이썬의 모든 객체를 파일로 저장할 수 있는 방법으로 DataFrame,List,Dict 등 모든 객체 저장 가능(특히 sklearn라이브러리를 통해 모델을 학습시키고, 저장할 때 많이 사용)

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * '1.3 seoul_people.csv'파일을 'seoul_people' 변수에 저장하고 그 Shape을 확인하세요.
#     * 데이터 파일 로딩시 참고 사항
#         * 구분자(sep)는 '\t' 입니다
#         * cp949 인코더를 사용해 주세요

# %%
import pandas as pd

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_people = pd.read_csv('1.3 seoul_people.csv',sep="\t", encoding = 'cp949')

# %%
# 데이터 프레임의 Shape을 확인합니다.
seoul_people.shape
# Out:
# (28, 14)

# %% [markdown]
# # 2.기본 정보 확인 및 클렌징
#
# + 데이터 클렌징 : 결측치, 이상치 등을 제거하여 데이터 분석 결과가 왜곡 되는 문제를 방지하기 위한 정제 과정

# %% [markdown]
# #### [실습문제2] 기본 정보 확인하기
# * 'seoul_people' 데이터의 정보를 확인해보세요.
# * 'describe', 'info', 'head' 등 전부 활용해 보겠습니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_people.describe()
# Out:
#               기간  자치구  세대  인구 인구.1 인구.2 인구.3 인구.4 인구.5   인구.6   인구.7   인구.8  \
# count         28   28  28  28   28   28   28   28   28     28     28     28
# unique         2   27  27  28   28   28   28   28   28     28     28     28
# top     2022.1/4  자치구  세대  합계   합계   합계  한국인  한국인  한국인  등록외국인  등록외국인  등록외국인
# freq          26    2   2   1    1    1    1    1    1      1      1      1
#
#         세대당인구  65세이상고령자
# count      28        28
# unique     24        27
# top     세대당인구  65세이상고령자
# freq        2         2

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   기간        28 non-null     object
#  1   자치구       28 non-null     object
#  2   세대        28 non-null     object
#  3   인구        28 non-null     object
#  4   인구.1      28 non-null     object
#  5   인구.2      28 non-null     object
#  6   인구.3      28 non-null     object
#  7   인구.4      28 non-null     object
#  8   인구.5      28 non-null     object
#  9   인구.6      28 non-null     object
#  10  인구.7      28 non-null     object
#  11  인구.8      28 non-null     object
#  12  세대당인구     28 non-null     object
#  13  65세이상고령자  28 non-null     object
# dtypes: object(14)
# memory usage: 3.2+ KB

# %%
seoul_people.head()
# Out:
#          기간  자치구       세대       인구     인구.1     인구.2     인구.3     인구.4  \
# 0        기간  자치구       세대       합계       합계       합계      한국인      한국인
# 1        기간  자치구       세대        계       남자       여자        계       남자
# 2  2022.1/4   합계  4451444  9732617  4716704  5015913  9506778  4613910
# 3  2022.1/4  종로구    73766   153684    74018    79666   144275    69911
# 4  2022.1/4   중구    63767   131450    63869    67581   122173    59448
#
#       인구.5    인구.6    인구.7    인구.8  세대당인구  65세이상고령자
# 0      한국인   등록외국인   등록외국인   등록외국인  세대당인구  65세이상고령자
# 1       여자       계      남자      여자  세대당인구  65세이상고령자
# 2  4892868  225839  102794  123045   2.14   1628980
# 3    74364    9409    4107    5302   1.96     28064
# 4    62725    9277    4421    4856   1.92     24742

# %% [markdown]
# #### [실습문제3] 데이터 확인 및 처리
#
# * head 와 tail 을 보고, 어느 데이터만 가져와야 할지 생각 해 봅시다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_people.tail()
# Out:
#           기간  자치구      세대      인구    인구.1    인구.2    인구.3    인구.4    인구.5  \
# 23  2022.1/4  관악구  279353  500336  250450  249886  486375  244409  241966
# 24  2022.1/4  서초구  169895  413677  197665  216012  409823  195806  214017
# 25  2022.1/4  강남구  234612  537338  257096  280242  532577  254866  277711
# 26  2022.1/4  송파구  285106  668261  321963  346298  662607  319407  343200
# 27  2022.1/4  강동구  201926  465097  227891  237206  461300  226203  235097
#
#      인구.6  인구.7  인구.8 세대당인구 65세이상고령자
# 23  13961  6041  7920  1.74    80686
# 24   3854  1859  1995  2.41    61404
# 25   4761  2230  2531  2.27    79575
# 26   5654  2556  3098  2.32    99854
# 27   3797  1688  2109  2.28    75477

# %%
seoul_people = pd.read_csv('1.3 seoul_people.csv',sep="\t", encoding = 'cp949', header = 2)

# %%
seoul_people.head()
# Out:
#          기간  자치구       세대        계       남자       여자      계.1     남자.1  \
# 0  2022.1/4   합계  4451444  9732617  4716704  5015913  9506778  4613910
# 1  2022.1/4  종로구    73766   153684    74018    79666   144275    69911
# 2  2022.1/4   중구    63767   131450    63869    67581   122173    59448
# 3  2022.1/4  용산구   111207   236518   114571   121947   222169   106735
# 4  2022.1/4  성동구   134533   291609   141662   149947   285073   138847
#
#       여자.1     계.2    남자.2    여자.2  세대당인구  65세이상고령자
# 0  4892868  225839  102794  123045   2.14   1628980
# 1    74364    9409    4107    5302   1.96     28064
# 2    62725    9277    4421    4856   1.92     24742
# 3   115434   14349    7836    6513   2.00     39461
# 4   146226    6536    2815    3721   2.12     46896

# %%
seoul_people.rename(columns = {'계':'총인구', '남자':'총남자수', '여자':'총여자수', '계.1':'총한국인수', '남자.1':'한국남자수', '여자.1':'한국여자수','계.2':'총외국인수', '남자.2':'외국남자수', '여자.2':'외국여자수'},inplace=True)

# %%
seoul_people.head()
# Out:
#          기간  자치구       세대      총인구     총남자수     총여자수    총한국인수    한국남자수  \
# 0  2022.1/4   합계  4451444  9732617  4716704  5015913  9506778  4613910
# 1  2022.1/4  종로구    73766   153684    74018    79666   144275    69911
# 2  2022.1/4   중구    63767   131450    63869    67581   122173    59448
# 3  2022.1/4  용산구   111207   236518   114571   121947   222169   106735
# 4  2022.1/4  성동구   134533   291609   141662   149947   285073   138847
#
#      한국여자수   총외국인수   외국남자수   외국여자수  세대당인구  65세이상고령자
# 0  4892868  225839  102794  123045   2.14   1628980
# 1    74364    9409    4107    5302   1.96     28064
# 2    62725    9277    4421    4856   1.92     24742
# 3   115434   14349    7836    6513   2.00     39461
# 4   146226    6536    2815    3721   2.12     46896

# %%
seoul_people.drop(columns=['기간','세대','세대당인구'],inplace = True)
seoul_people.head()
# Out:
#    자치구      총인구     총남자수     총여자수    총한국인수    한국남자수    한국여자수   총외국인수   외국남자수  \
# 0   합계  9732617  4716704  5015913  9506778  4613910  4892868  225839  102794
# 1  종로구   153684    74018    79666   144275    69911    74364    9409    4107
# 2   중구   131450    63869    67581   122173    59448    62725    9277    4421
# 3  용산구   236518   114571   121947   222169   106735   115434   14349    7836
# 4  성동구   291609   141662   149947   285073   138847   146226    6536    2815
#
#     외국여자수  65세이상고령자
# 0  123045   1628980
# 1    5302     28064
# 2    4856     24742
# 3    6513     39461
# 4    3721     46896

# %%
seoul_people.drop(0,axis=0, inplace = True)
seoul_people.head()
# Out:
#    자치구     총인구    총남자수    총여자수   총한국인수   한국남자수   한국여자수  총외국인수  외국남자수  외국여자수  \
# 1  종로구  153684   74018   79666  144275   69911   74364   9409   4107   5302
# 2   중구  131450   63869   67581  122173   59448   62725   9277   4421   4856
# 3  용산구  236518  114571  121947  222169  106735  115434  14349   7836   6513
# 4  성동구  291609  141662  149947  285073  138847  146226   6536   2815   3721
# 5  광진구  353110  169525  183585  340707  164346  176361  12403   5179   7224
#
#    65세이상고령자
# 1     28064
# 2     24742
# 3     39461
# 4     46896
# 5     52604

# %%
seoul_people = seoul_people.sort_values(by=['총인구'])

# %%
seoul_people.head(25)
# Out:
#      자치구     총인구    총남자수    총여자수   총한국인수   한국남자수   한국여자수  총외국인수  외국남자수  외국여자수  \
# 2     중구  131450   63869   67581  122173   59448   62725   9277   4421   4856
# 1    종로구  153684   74018   79666  144275   69911   74364   9409   4107   5302
# 3    용산구  236518  114571  121947  222169  106735  115434  14349   7836   6513
# 18   금천구  244901  123959  120942  231098  116568  114530  13803   7391   6412
# 4    성동구  291609  141662  149947  285073  138847  146226   6536   2815   3721
# 9    강북구  300824  145934  154890  297384  144643  152741   3440   1291   2149
# 13  서대문구  317075  149805  167270  305866  145958  159908  11209   3847   7362
# 10   도봉구  318100  154440  163660  316098  153716  162382   2002    724   1278
# 6   동대문구  352592  172318  180274  337982  166823  171159  14610   5495   9115
# 5    광진구  353110  169525  183585  340707  164346  176361  12403   5179   7224
# 14   마포구  378629  176886  201743  368331  173073  195258  10298   3813   6485
# 7    중랑구  393600  193623  199977  389043  191835  197208   4557   1788   2769
# 20   동작구  394649  190377  204272  386017  186648  199369   8632   3729   4903
# 19  영등포구  400241  198080  202161  376740  185696  191044  23501  12384  11117
# 22   서초구  413677  197665  216012  409823  195806  214017   3854   1859   1995
# 17   구로구  419984  208027  211957  396017  195002  201015  23967  13025  10942
# 8    성북구  442680  212277  230403  433150  208691  224459   9530   3586   5944
# 15   양천구  449378  219882  229496  446182  218554  227628   3196   1328   1868
# 25   강동구  465097  227891  237206  461300  226203  235097   3797   1688   2109
# 12   은평구  476013  227172  248841  472259  225640  246619   3754   1532   2222
# 21   관악구  500336  250450  249886  486375  244409  241966  13961   6041   7920
# 11   노원구  514445  247417  267028  510486  245663  264823   3959   1754   2205
# 23   강남구  537338  257096  280242  532577  254866  277711   4761   2230   2531
# 16   강서구  578426  277797  300629  573046  275422  297624   5380   2375   3005
# 24   송파구  668261  321963  346298  662607  319407  343200   5654   2556   3098
#
#     65세이상고령자
# 2      24742
# 1      28064
# 3      39461
# 18     41819
# 4      46896
# 9      64961
# 13     55012
# 10     65122
# 6      62963
# 5      52604
# 14     55168
# 7      72851
# 20     67470
# 19     63547
# 22     61404
# 17     73864
# 8      75719
# 15     69953
# 25     75477
# 12     88418
# 21     80686
# 11     89426
# 23     79575
# 16     93924
# 24     99854

# %%
# 해당 데이터프레임을 'df_seoul_people.csv' 파일로 저장하세요.
seoul_people.to_csv("df_seoul_people.csv", index = False)

# %% [markdown]
# # 3.데이터 분석하기
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 데이터들의 패턴 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='nanum')
sns.set(font="HYGungSo-Bold",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# #### [실습문제4] 데이터 분포 알아보기
# * 다양한 변수를 기준으로 그래프를 그려보고 인사이트를 도출해보세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_people["남자비율"] = seoul_people['총남자수'] / seoul_people["총인구"]

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
plt.figure(figsize=(20,4))
plt.plot('자치구', '남자비율', data = seoul_people)

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 20,4
sns.lineplot(data = seoul_people, x= '자치구', y='남자비율')
# Out:
# <AxesSubplot:xlabel='자치구', ylabel='남자비율'>

# %%
sns.displot(seoul_people['남자비율'])

# %%
# 위 차트를 통해 알게된 사실을 정리해봅시다.
# 1. 
# 2.
# 3

# %% [markdown]
# ---
